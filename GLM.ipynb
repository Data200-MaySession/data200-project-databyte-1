# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm 

from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
x = np.linspace(-10,10,100)
y = sigmoid (x)

# %%
plt.plot (x,y)
plt.grid()

# %%
X,y = make_classification(n_samples=100,n_features=2, n_informative=2,n_redundant=0,random_state=42)

# %%
print ("InDependent Variable: ",display(pd.DataFrame(X, columns = ["Feature 1", "Feature 2"])))
print ("Dependent Variable: ",display(pd.DataFrame(y, columns = ["Target"])))
# Out:
#     Feature 1  Feature 2
# 0    0.559426   2.388694
# 1    1.312175  -0.717315
# 2   -1.559849  -1.924874
# 3   -2.281386  -0.136856
# 4    1.560704  -0.427958
# ..        ...        ...
# 95   1.804741  -0.149941
# 96   1.154661  -0.955482
# 97  -0.567725   1.389918
# 98  -1.158068   0.865620
# 99  -1.755186   0.360170
#
# [100 rows x 2 columns]
# InDependent Variable:  None
#     Target
# 0        0
# 1        1
# 2        0
# 3        0
# 4        1
# ..     ...
# 95       1
# 96       1
# 97       0
# 98       0
# 99       0
#
# [100 rows x 1 columns]
# Dependent Variable:  None

# %%
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y)
# plt.title("Scatter Plot of Features")
# plt.xlabel("Feature 1")
# plt.ylabel("Feature 2")
# plt.legend(title="Target")
# plt.show()
# Out:
# <Axes: >

# %%
X_with_intercept = sm.add_constant(X)

model = sm.Logit (y,X_with_intercept).fit()
print (model.params)
print (model.summary())
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 35
# [  55.99411377  546.5573295  -313.31994579]
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  100
# Model:                          Logit   Df Residuals:                       97
# Method:                           MLE   Df Model:                            2
# Date:                Tue, 27 May 2025   Pseudo R-squ.:                   1.000
# Time:                        08:47:31   Log-Likelihood:            -4.9524e-05
# converged:                      False   LL-Null:                       -69.315
# Covariance Type:            nonrobust   LLR p-value:                 7.889e-31
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         55.9941    751.907      0.074      0.941   -1417.717    1529.705
# x1           546.5573   7134.358      0.077      0.939   -1.34e+04    1.45e+04
# x2          -313.3199   4136.859     -0.076      0.940   -8421.414    7794.774
# ==============================================================================
#
# Complete Separation: The results show that there iscomplete separation or perfect prediction.
# In this case the Maximum Likelihood Estimator does not exist and the parameters
# are not identified.
# /Users/aarohan/pinokio/bin/miniconda/lib/python3.10/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/aarohan/pinokio/bin/miniconda/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/aarohan/pinokio/bin/miniconda/lib/python3.10/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))

# %%
coef = model.params
intercept = coef [0]
slope1 = coef [1]
slope2 = coef [2]
print ("M1: ", slope1, "M2: ", slope2, "c: ", intercept)
# Out:
# M1:  546.5573295021713 M2:  -313.3199457882781 c:  55.99411376674706

# %%
s_x_vals = np.linspace(X[:, 0].min(), X[:, 0].max(), 100)
s_y_vals = (
    -(slope1 * s_x_vals + intercept) / slope2
)  # Solve for X2 in terms of X1 and coefficients
plt.figure(figsize=(15, 8))
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y)
plt.plot(s_x_vals, s_y_vals, color="black", linestyle="--")
plt.title("Logistic Regression Decision Boundary (Statsmodels)", fontsize=14)
plt.xlabel("Feature 1", fontsize=8)
plt.ylabel("Feature 2", fontsize=8)
plt.legend()
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y)
# Out:
# <Axes: title={'center': 'Logistic Regression Decision Boundary (Statsmodels)'}, xlabel='Feature 1', ylabel='Feature 2'>

# %%
print("\nTesting if it will get pushed or not")
# Out:
# Testing if it will get pushed or not
